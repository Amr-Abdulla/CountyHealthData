# %%
import os
from google.colab import drive

# %% [markdown]
# I used this code to import my county health data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# I imported pandas to this colab so I can run all of these codes with the different kinds of data.

# %%
df=pd.read_csv('gdrive/CountyHealthData_2014-2015 (1).csv')

# %% [markdown]
# I used the county health data as my main resource for all the data I am using for this project.

# %%
df.size
# Out:
# 390976

# %% [markdown]
# This gives the size of the data that I am taking and manipulating from.

# %%
df.size == 6109 * 64
# Out:
# True

# %% [markdown]
# This tells that the size of the data is true.

# %%
df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
# ...

# %% [markdown]
# This is a list of the columns different kind of stats that the public county health data contains. I will be using these stats to manupliate my data.

# %%
df.dtypes
# Out:
# State                                object
# Region                               object
# Division                             object
# County                               object
# FIPS                                  int64
#                                      ...
# Other primary care providers        float64
# Median household income               int64
# Children eligible for free lunch    float64
# Homicide rate                       float64
# Inadequate social support           float64
# Length: 64, dtype: object

# %% [markdown]
# This data gives me the different types that I can use for my research.

# %%
df.sample(n=5)
# Out:
#      State     Region            Division             County   FIPS  GEOID  \
# 735     FL      South      South Atlantic      Sumter County  12119  12119
# 881     GA      South      South Atlantic      Greene County  13133  13133
# 425     CA       West             Pacific  Sacramento County   6067   6067
# 2393    ME  Northeast         New England  Cumberland County  23005  23005
# 5883    WI    Midwest  East North Central   Marinette County  55075  55075
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 735   Region 15  1/1/2015           7493.0                0.148  ...
# 881   Region 24  1/1/2015           8647.0                0.192  ...
# 425   Region 26  1/1/2015           6353.0                0.139  ...
# 2393  Region 12  1/1/2014           5355.0                0.098  ...
# 5883   Region 6  1/1/2014           6701.0                0.150  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# ...

# %% [markdown]
# This is just a sample code that I ran too see what kind of different stats it will give me and if it will be usefull.

# %%
print(df.Region.shape)
print(df.Region.dtypes)
# Out:
# (6109,)
# object

# %%
df.Region.shape
# Out:
# (6109,)

# %%
print(df.Region.dtypes)
# Out:
# object

# %%
df.dtypes.value_counts()
# Out:
# float64    54
# object      6
# int64       4
# Name: count, dtype: int64

# %% [markdown]
# This data type gives me different value contents that I can use.

# %%
df.State.value_counts()
# Out:
# State
# TX    469
# GA    318
# VA    266
# KY    240
# MO    229
# IL    204
# NC    200
# KS    199
# IA    198
# TN    190
# IN    184
# OH    176
# MN    174
# MI    164
# MS    163
# NE    157
# OK    154
# AR    150
# WI    144
# FL    134
# PA    134
# AL    134
# LA    128
# NY    124
# CO    119
# SD    117
# CA    114
# WV    110
# ND     92
# MT     92
# SC     92
# ID     84
# WA     78
# OR     67
# NM     64
# UT     54
# MD     48
# AK     46
# WY     46
# NJ     42
# NV     32
# ME     32
# AZ     30
# MA     28
# VT     28
# NH     20
# CT     16
# RI     10
# HI      8
# DE      6
# DC      1
# Name: count, dtype: int64

# %% [markdown]
# This data from the county health data gives me all the states value counts and will happen me with the specific data I need.

# %%
df[df["State"] == "NC"]
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %% [markdown]
# I am using this piece of data from the county health data to see a fair amount of data in North Carolina especially in the south Atlatnic divison to get a gist of the different stats from each county.

# %%
df.loc[df["State"] == "NC", ["County", "Adult smoking"]].head()
# Out:
#                 County  Adult smoking
# 3243   Alamance County          0.238
# 3244   Alamance County          0.238
# 3245  Alexander County          0.260
# 3246  Alexander County          0.260
# 3247  Alleghany County          0.271

# %% [markdown]
# I am usings the county health data about Adult smoking in North Carolina to determine the different rates between these five counties.

# %%
df.loc[df["State"] == "NC", ["County", "Adult obesity"]].head()
# Out:
#                 County  Adult obesity
# 3243   Alamance County          0.341
# 3244   Alamance County          0.332
# 3245  Alexander County          0.272
# 3246  Alexander County          0.283
# 3247  Alleghany County          0.247

# %% [markdown]
# I am using the county health data to analyze the different rates in obesity in 5 counties in North Carolina.

# %%
df.loc[df["State"] == "NC", ["County", "Excessive drinking"]].head()
# Out:
#                 County  Excessive drinking
# 3243   Alamance County               0.123
# 3244   Alamance County               0.123
# 3245  Alexander County               0.119
# 3246  Alexander County               0.119
# 3247  Alleghany County               0.165

# %% [markdown]
# I am using the county health data to see the differences between each five counties in North CArolina in excessive drinking.

# %%
df.loc[df["State"] == "NC", ["County", "Poor mental health days"]].head()
# Out:
#                 County  Poor mental health days
# 3243   Alamance County                      3.6
# 3244   Alamance County                      3.6
# 3245  Alexander County                      4.6
# 3246  Alexander County                      4.6
# 3247  Alleghany County                      4.4

# %% [markdown]
# I am using the county health data to see the poor mental health days in North Carolina counties and compare the differences and if they are major or minor.

# %% [markdown]
# After all of the data I have compiled I will be using it to offer a future anaylysis for people that will look at my work. The kind of potential applications working with this data pose a new sense in the right direction espically with the poor mental health days, excessove drinking, and adult smoking and after users analyze this data they might come up with a solution for these problems.
